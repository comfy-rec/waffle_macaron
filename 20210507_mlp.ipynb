# %%
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join
import numpy as np
import cv2
mypath="C:\\Users\\KBCI\\mw"
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
images = np.empty(len(onlyfiles), dtype=object)
for n in range(0, len(onlyfiles)):
    images[n] = cv2.imread(join(mypath, onlyfiles[n]), cv2.IMREAD_COLOR)

# %%
rimages = np.empty(len(onlyfiles), dtype=object)
frimages = np.empty(len(onlyfiles), dtype=object)

for i in range(len(images)):
    b, g, r = cv2.split(images[i])
    images[i] = cv2.merge([r, g, b])
    rimages[i] = cv2.resize(images[i], dsize=(50, 50), interpolation=cv2.INTER_AREA)
    frimages[i] = rimages[i].flatten()

# %%
plt.imshow(images[3])
plt.show()

# %%
plt.imshow(rimages[0])

# %%
import cv2
from matplotlib import pyplot as plt

hist = cv2.calcHist([images[3]], [0], None, [256], [0, 256])
plt.hist(images[3], 256, [0, 256]);
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-8648057f7286> in <module>
#       3
#       4 hist = cv2.calcHist([images[3]], [0], None, [256], [0, 256])
# ----> 5 plt.hist(images[3], 256, [0, 256]);
#       6 plt.show()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
color = ('b', 'g', 'r')
for i, col in enumerate(color):
    histr = cv2.calcHist([img], [i], None, [256], [0, 256])
    plt.plot(histr, color = col)
    plt.xlim([0, 256])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-27-0cb47d10da93> in <module>
#       1 color = ('b', 'g', 'r')
#       2 for i, col in enumerate(color):
# ----> 3     histr = cv2.calcHist([img], [i], None, [256], [0, 256])
#       4     plt.plot(histr, color = col)
#       5     plt.xlim([0, 256])
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-kh7iq4w7\opencv\modules\imgproc\src\histogram.cpp:160: error: (-215:Assertion failed) j < nimages in function 'cv::histPrepareImages'

# %%
tfrimages = [[0 for col in range(750)] for row in range(204)]

for i in range(len(frimages)):
    tfrimages[i] = list(frimages[i])

# %%
limages = np.empty(len(onlyfiles), dtype=object)

for i in range(len(images)):
    limages[i] = "waffle"

# %%
import sklearn.model_selection as model_selection 
import sklearn.neural_network as neural_network 
import sklearn.preprocessing as preprocessing

imageNDArray = tfrimages
labelNDArray = limages
imageNDArray = preprocessing.normalize(imageNDArray, norm = "l2") # "l1" 정규화도 사용 가능하다. 
trainImageNDArray, testImageNDArray, trainLabelNDArray, testLabelNDArray = model_selection.train_test_split(imageNDArray, labelNDArray, test_size = 0.25, random_state = 17) 
mlpClassifier = neural_network.MLPClassifier(hidden_layer_sizes = (3, 3, 3), max_iter = 50, solver = "sgd", learning_rate_init = 0.01, verbose = True) 
print("신경망 학습을 시작합니다...") 
mlpClassifier.fit(trainImageNDArray, trainLabelNDArray) 
print("신경망 학습을 완료했습니다.") 
print("네트워크 성능 : %f" % mlpClassifier.score(testImageNDArray, testLabelNDArray))
# Out:
# 신경망 학습을 시작합니다...
# Iteration 1, loss = 0.79527512
# Iteration 2, loss = 0.77848669
# Iteration 3, loss = 0.75518669
# Iteration 4, loss = 0.72666465
# Iteration 5, loss = 0.69422620
# Iteration 6, loss = 0.65900110
# Iteration 7, loss = 0.62174523
# Iteration 8, loss = 0.58319019
# Iteration 9, loss = 0.54402994
# Iteration 10, loss = 0.50488009
# Iteration 11, loss = 0.46626794
# Iteration 12, loss = 0.42863867
# Iteration 13, loss = 0.39236109
# Iteration 14, loss = 0.35773163
# Iteration 15, loss = 0.32497966
# Iteration 16, loss = 0.29427053
# Iteration 17, loss = 0.26570984
# Iteration 18, loss = 0.23934818
# Iteration 19, loss = 0.21518700
# Iteration 20, loss = 0.19318528
# Iteration 21, loss = 0.17326702
# Iteration 22, loss = 0.15532888
# Iteration 23, loss = 0.13924774
# Iteration 24, loss = 0.12488777
# Iteration 25, loss = 0.11210664
# Iteration 26, loss = 0.10076079
# Iteration 27, loss = 0.09070956
# Iteration 28, loss = 0.08181830
# Iteration 29, loss = 0.07396054
# ...
